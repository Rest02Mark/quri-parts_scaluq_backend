# %%
from quri_parts.circuit import X, RX, CNOT
from math import pi
from quri_parts.qulacs.circuit import convert_circuit
from quri_parts.circuit import QuantumCircuit

# Create a circuit for 3 qubits
circuit = QuantumCircuit(3)
# Add an already created QuantumGate object
circuit.add_gate(X(0))
# Or use methods to add gates
circuit.add_X_gate(0)
circuit.add_RX_gate(1, pi/3)
circuit.add_CNOT_gate(2, 1)
circuit.add_PauliRotation_gate(target_qubits=(0, 1, 2), pauli_id_list=(1, 2, 3), angle=pi/3)

# %%
import sys
from quri_parts.circuit import X, RX, CNOT
from math import pi
from quri_parts.qulacs.circuit import convert_circuit
from quri_parts.circuit import QuantumCircuit

sys.path.append("/home/rest/baito/quri-parts/packages/scaluq")
import quri_parts.scaluq as aaa
import quri_parts.scaluq.circuit as aaa_circuit


aaa.helper_function()
aaa_circuit.scaluq_circuit_helper_function()

#scaluq_aaa.helper_function()
#scaluq_aaa.circuit.scaluq_circuit_helper_function()
#scaluq_aaa.circuit.kakunin(circuit)

c = QuantumCircuit(2)
c.add_Identity_gate(0)
#c.add_Pauli_gate([0, 1], [1, 2])
#c.add_UnitaryMatrix_gate([0], [[1, 0], [0, 1]])

scaluq_circuit = aaa_circuit.convert_circuit_f32(c)
aaa_circuit.kakunin(c)
print(scaluq_circuit)

#from packages.scaluq.quri_parts import scaluq_aaa

#scaluq_aaa.helper_function()
# Out:
# helper function from quri_parts
# helper function from scaluq/circuit
# in convert_gate_f32 and gate.name is  Identity
# Kokkos::OpenMP::initialize WARNING: OMP_PROC_BIND environment variable not set
#   In general, for best performance with OpenMP 4.0 or better set OMP_PROC_BIND=spread and OMP_PLACES=threads
#   For best performance with OpenMP 3.1 set OMP_PROC_BIND=true
#   For unit testing set OMP_PROC_BIND=false
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      20 c.add_Identity_gate(0)
#      21 #c.add_Pauli_gate([0, 1], [1, 2])
#      22 #c.add_UnitaryMatrix_gate([0], [[1, 0], [0, 1]])
# ---> 24 scaluq_circuit = aaa_circuit.convert_circuit_f32(c)
#      25 aaa_circuit.kakunin(c)
#      26 print(scaluq_circuit)
#
# File ~/baito/quri-parts/packages/scaluq/quri_parts/scaluq/circuit/__init__.py:266, in convert_circuit_f32(circuit)
#     262 scaluq_f32_circuit = scaluq.f32.Circuit(circuit.qubit_count)
#     264 for gate in circuit.gates:
#     265     #print(convert_gate_f32(gate))
# --> 266     scaluq_f32_circuit.add_gate(convert_gate_f32(gate))
#     268 print("convert end f32.")
#     270 return scaluq_f32_circuit
#
# File ~/baito/quri-parts/packages/scaluq/quri_parts/scaluq/circuit/__init__.py:215, in convert_gate_f32(gate)
#     213 if is_single_qubit_gate_name(gate.name):
#     214     if gate.name in _single_qubit_gate_scaluq_f32:
# --> 215         return _single_qubit_gate_scaluq_f32[gate.name](
#     216             *gate.target_indices, *gate.params
#     217         )
#     218     elif gate.name == gate_names.U1:
#     219         return _u1_gate_scaluq_f32(gate)
#
# TypeError: I(): incompatible function arguments. The following argument types are supported:
#     1. I() -> scaluq.scaluq_core.f32.Gate
#
# Invoked with types: int

# %%
from quri_parts.circuit import X, RX, CNOT
from math import pi
from quri_parts.qulacs.circuit import convert_circuit
from quri_parts.circuit import QuantumCircuit
import sys
sys.path.append("/home/rest/baito/quri-parts/packages/scaluq")
import quri_parts.scaluq as aaa
import quri_parts.scaluq.circuit as aaa_circuit

import tests.circuit.test_convert_circuit as test_convert_circuit

test_convert_circuit.a()
#test_convert_circuit.test_convert_single_qubit_gate_f32()
#test_convert_circuit.test_convert_two_qubit_gate_f32()
#test_convert_circuit.test_convert_three_qubit_gate_f32()
#test_convert_circuit.test_convert_rotation_gate_f32()
#test_convert_circuit.test_convert_unitary_matrix_gate_f32()
#test_convert_circuit.test_convert_u_gate_f32()
#test_convert_circuit.test_convert_pauli_gate_f32()
#test_convert_circuit.test_convert_pauli_rotation_gate_f32()
test_convert_circuit.test_convert_gate_circuit_f32()
#from tests.circuit.test_convert_circuit import a
#a()
# Out:
# helper function from scaluq/circuit
# in convert_gate_f32 and gate.name is  X
# in convert_gate_f32 and gate.name is  H
# in convert_gate_f32 and gate.name is  CNOT
# in convert_gate_f32 and gate.name is  RX
# in convert_gate_f32 and gate.name is  TOFFOLI
# convert end f32.
# Kokkos::OpenMP::initialize WARNING: OMP_PROC_BIND environment variable not set
#   In general, for best performance with OpenMP 4.0 or better set OMP_PROC_BIND=spread and OMP_PLACES=threads
#   For best performance with OpenMP 3.1 set OMP_PROC_BIND=true
#   For unit testing set OMP_PROC_BIND=false
